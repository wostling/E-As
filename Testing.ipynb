# %%
import numpy as np


import matplotlib

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import LogNorm

# %%
from astropy.io import fits

# %%
"C:/Users/willi/Desktop/Hubble Data/candidates/1/hst_06773_03_wfpc2_f450w_pc_sci.fits"
# Out:
# 'C:/Users/willi/Desktop/Hubble Data/candidates/1/hst_06773_03_wfpc2_f450w_pc_sci.fits'

# %%
image_data = fits.getdata("C:/Users/willi/Desktop/Hubble Data/candidates/1/hst_06773_03_wfpc2_f450w_pc_sci.fits")
print(type(image_data))
print(image_data.shape)
# Out:
# <class 'numpy.ndarray'>
# (1000, 1000)

# %%
plt.imshow(image_data, cmap='gray')
plt.colorbar()

# %%
print('Min:', np.min(image_data))
print('Max:', np.max(image_data))
print('Mean:', np.mean(image_data))
print('Stdev:', np.std(image_data))
# Out:
# Min: -3.9064257
# Max: 340.00992
# Mean: 0.01367251
# Stdev: 1.050172

# %%
print(type(image_data.flatten()))
# Out:
# <class 'numpy.ndarray'>

# %%
NBINS = 1000
histogram = plt.hist(image_data.flatten(), NBINS)

# %%
plt.imshow(image_data, cmap='gray', norm=LogNorm())

# I chose the tick marks based on the histogram above
cbar = plt.colorbar(ticks=[5.e3,1.e4,2.e4])
cbar.ax.set_yticklabels(['5,000','10,000','20,000'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dd050853ba18> in <module>
# ----> 1 plt.imshow(image_data, cmap='gray', norm=LogNorm())
#       2
#       3 # I chose the tick marks based on the histogram above
#       4 cbar = plt.colorbar(ticks=[5.e3,1.e4,2.e4])
#       5 cbar.ax.set_yticklabels(['5,000','10,000','20,000'])
#
# NameError: name 'plt' is not defined
