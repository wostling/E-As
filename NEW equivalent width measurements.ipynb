# %%
get_ipython().run_line_magic('pylab', 'inline')
from astropy.io import fits
from astropy import units as u
import numpy as np
from matplotlib import pyplot as plt
from astropy.visualization import quantity_support
from scipy.interpolate import interp1d
quantity_support()  # for getting units on the axes below
from specutils import SpectralRegion
from specutils.analysis import equivalent_width
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#plate, mjd, fiberid, redshift = np.loadtxt('Leodata.csv', delimiter=',', skiprows = 1, usecols = (9,10,11,16), unpack = True)
#x =2

#get this link by going to the galaxy's SDSS page and copying the link from "get FITS file"
#f = fits.open("http://dr15.sdss.org/optical/spectrum/view/data/format=fits?plateid="+str(int(plate[x]))+"&mjd="+str(int(mjd[x]))+"&fiberid="+str(int(fiberid[x]))+"&reduction2d=v5_7_0")  

f = fits.open("http://dr15.sdss.org/optical/spectrum/view/data/format=fits?plateid=2240&mjd=53823&fiberid=512&reduction2d=v5_7_0")  
redshift = 0.028893

# The spectrum is in the second HDU of this file.
specdata = f[1].data 
f.close()

# %%
#turn data into AstroPy quantities & plot
from specutils import Spectrum1D
lamb = 10**specdata['loglam'] * u.AA 
flux = specdata['flux'] * u.Unit('1e-17 erg cm-2 s-1 AA-1') 
spec = Spectrum1D(spectral_axis=lamb, flux=flux) 
f, ax = plt.subplots()  
ax.step(spec.spectral_axis[::2], spec.flux[::2], linewidth = .5)
wavelengths = spec.spectral_axis.value
flux = flux.value

# %% [markdown]
# ### if you get an error running the code below, increase the tolerance factor (like 0.3, 0.8)

# %%
redshift = 0.028893
percent_error = 5

h_alpha = 6563 * redshift + 6563
h_beta = 4861 * redshift + 4861
h_gamma = 4340 * redshift + 4340
h_delta = 4102 * redshift + 4102

# %% [markdown]
# H Alpha below!

# %%
wave = h_alpha

up = (100 + percent_error)/100
down = (100- percent_error)/100

dip_region = (wavelengths < (wave+25)) & (wavelengths > (wave-25)) #central region where the dip occurs
dip_region_rhs = (wavelengths > (wave)) & (wavelengths < (wave+25)) #right hand side within the dip region (helpful for setting right bound)
dip_region_lhs = (wavelengths < (wave)) & (wavelengths > (wave-25)) #left hand side within the dip region

rightregion = (wavelengths < (wave+75)) & (wavelengths > (wave+25)) #region to the right-hand side of dip
leftregion= (wavelengths > (wave-75)) & (wavelengths < (wave-25)) #region to the left-hand side of dip

joined_list = [*flux[rightregion], *flux[leftregion]] #to find continuum, average values from
# the RHS and LHS regions right outside dip region. have to first combine those 2 arrays into
# one long one
continuum = np.average(joined_list) #and then average that new array!
func = interp1d(wavelengths[dip_region], flux[dip_region], kind = 'linear') #linear interpolation of dip region
# (literally connect the dots, but now I can get flux values from the lines connecting the dots)

#create interpolation of RHS so I can find the right bound
x_rhs = np.linspace(wave, wavelengths[dip_region][-1], 5000)
y_rhs = func(x_rhs)

#create interpolation of LHS so I can find the left bound
x_lhs = np.linspace(wavelengths[dip_region][0], wave, 5000)
y_lhs = func(x_lhs)

plt.figure(figsize=(10,8))
plt.plot(spec.spectral_axis, spec.flux)

continuum_new = continuum + 0 #if you think the suggested one is wrong, add/subtract a bit!


tolerance = 0.8 #how close does the continuum need to be to the interpolation?
#can make this small for gradual spikes, big for very sharp spikes
leftbound = x_lhs[(np.abs(y_lhs - continuum_new) < tolerance)][-1] # the [-1] at the end means to 
# take the last array element of this, which would be the most central one (ie the one we want)
# instead of a value on the left or something
rightbound = x_rhs[(np.abs(y_rhs - continuum_new) < tolerance)][0] 


leftbound_new = leftbound + 0
rightbound_new = rightbound + 0


plt.ylim(continuum_new - 10, continuum_new + 5)
plt.xlim(wave-100, wave+100)

plt.plot(wavelengths[dip_region], func(wavelengths[dip_region]))
plt.axvline(rightbound_new, color="orange", linestyle="--", linewidth = "1")
plt.axvline(leftbound_new, color="orange", linestyle="--", linewidth = "1")
plt.axhline(y=continuum_new, color="orange", linestyle="--", linewidth = "1")
plt.axvline(wave, color="blue", linestyle="--", linewidth = "1") #approximate wavelength of line

li = np.where((spec.spectral_axis>leftbound_new*u.AA) & (spec.spectral_axis<rightbound_new*u.AA))
plt.fill_between(spec.spectral_axis[li], y1=continuum_new, y2=spec.flux[li], alpha = .2)
plt.show()

print("suggested continuum: {:.3f} A ".format(continuum))
print("continuum in use: {:.3f} A ".format(continuum_new))
print("EW with continuum in use: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=continuum_new* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
print("Top error continum: {:.3f} A ".format(continuum*up))
print("Top error: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=(continuum_new * up)* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
print("Lower error continum {:.3f} A ".format(continuum*down))
print("Bottom Error: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=(continuum_new * down)* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
# Out:
# suggested continuum: 4.673 A
# continuum in use: 4.673 A
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-62890f992e4d> in <module>
#      59 print("suggested continuum: {:.3f} A ".format(continuum))
#      60 print("continuum in use: {:.3f} A ".format(continuum_new))
# ---> 61 print("EW with continuum in use: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=continuum_new* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
#      62 print("Top error continum: {:.3f} A ".format(continuum*up))
#      63 print("Top error: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=(continuum_new * up)* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
#
# ~\anaconda3\lib\site-packages\specutils\analysis\flux.py in equivalent_width(spectrum, continuum, regions, mask_interpolation)
#     105
#     106     kwargs = dict(continuum=continuum)
# --> 107     return computation_wrapper(_compute_equivalent_width, spectrum, regions,
#     108                                mask_interpolation=mask_interpolation, **kwargs)
#     109
#
# ~\anaconda3\lib\site-packages\specutils\analysis\utils.py in computation_wrapper(func, spectrum, region, **kwargs)
#      21     # Single region
#      22     elif isinstance(region, SpectralRegion):
# ---> 23         return func(spectrum, regions=region, **kwargs)
#      24
#      25     # List of regions
#
# ~\anaconda3\lib\site-packages\specutils\analysis\flux.py in _compute_equivalent_width(spectrum, continuum, regions, mask_interpolation)
#     185     cont_spec = Spectrum1D(flux=continuum,
#     186                            spectral_axis=spectrum.spectral_axis)
# --> 187     cont_flux = _compute_line_flux(cont_spec,
#     188                                    mask_interpolation=mask_interpolation)
#     189     line_flux = _compute_line_flux(spectrum,
#
# ~\anaconda3\lib\site-packages\specutils\analysis\flux.py in _compute_line_flux(spectrum, regions, mask_interpolation)
#     132         flux = calc_spectrum.flux
#     133
# --> 134     dx = np.abs(np.diff(calc_spectrum.spectral_axis.bin_edges))
#     135     line_flux = np.sum(flux * dx)
#     136
#
# ~\anaconda3\lib\site-packages\astropy\utils\decorators.py in __get__(self, obj, owner)
#     756                 return val
#     757             else:
# --> 758                 val = self.fget(obj)
#     759                 obj.__dict__[self._key] = val
#     760                 return val
#
# ~\anaconda3\lib\site-packages\specutils\spectra\spectral_axis.py in bin_edges(self)
#      68             return self._bin_edges
#      69         else:
# ---> 70             return self._edges_from_centers(self.value, self.unit)
#      71
#      72     def with_observer_stationary_relative_to(self, frame,
#
# ~\anaconda3\lib\site-packages\specutils\spectra\spectral_axis.py in _edges_from_centers(centers, unit)
#      47         to the beginning and end of the spectral axis.
#      48         """
# ---> 49         a = np.insert(centers, 0, 2*centers[0] - centers[1])
#      50         b = np.append(centers, 2*centers[-1] - centers[-2])
#      51         edges = (a + b) / 2
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %% [markdown]
# H_ beta!

# %%
wave = h_beta

up = (100 + percent_error)/100
down = (100- percent_error)/100

dip_region = (wavelengths < (wave+25)) & (wavelengths > (wave-25)) #central region where the dip occurs
dip_region_rhs = (wavelengths > (wave)) & (wavelengths < (wave+25)) #right hand side within the dip region (helpful for setting right bound)
dip_region_lhs = (wavelengths < (wave)) & (wavelengths > (wave-25)) #left hand side within the dip region

rightregion = (wavelengths < (wave+75)) & (wavelengths > (wave+25)) #region to the right-hand side of dip
leftregion= (wavelengths > (wave-75)) & (wavelengths < (wave-25)) #region to the left-hand side of dip

joined_list = [*flux[rightregion], *flux[leftregion]] #to find continuum, average values from
# the RHS and LHS regions right outside dip region. have to first combine those 2 arrays into
# one long one
continuum = np.average(joined_list) #and then average that new array!
func = interp1d(wavelengths[dip_region], flux[dip_region], kind = 'linear') #linear interpolation of dip region
# (literally connect the dots, but now I can get flux values from the lines connecting the dots)

#create interpolation of RHS so I can find the right bound
x_rhs = np.linspace(wave, wavelengths[dip_region][-1], 5000)
y_rhs = func(x_rhs)

#create interpolation of LHS so I can find the left bound
x_lhs = np.linspace(wavelengths[dip_region][0], wave, 5000)
y_lhs = func(x_lhs)

plt.figure(figsize=(10,8))
plt.plot(spec.spectral_axis, spec.flux)

continuum_new = continuum #if you think the suggested one is wrong, add/subtract a bit!


tolerance = 0.8 #how close does the continuum need to be to the interpolation?
#can make this small for gradual spikes, big for very sharp spikes
leftbound = x_lhs[(np.abs(y_lhs - continuum_new) < tolerance)][-1] # the [-1] at the end means to 
# take the last array element of this, which would be the most central one (ie the one we want)
# instead of a value on the left or something
rightbound = x_rhs[(np.abs(y_rhs - continuum_new) < tolerance)][0] 


leftbound_new = leftbound + 0
rightbound_new = rightbound + 0



plt.ylim(continuum_new - 10, continuum_new + 5)
plt.xlim(wave-100, wave+100)

plt.plot(wavelengths[dip_region], func(wavelengths[dip_region]))
plt.axvline(rightbound_new, color="orange", linestyle="--", linewidth = "1")
plt.axvline(leftbound_new, color="orange", linestyle="--", linewidth = "1")
plt.axhline(y=continuum_new, color="orange", linestyle="--", linewidth = "1")
plt.axvline(wave, color="blue", linestyle="--", linewidth = "1") #approximate wavelength of line

li = np.where((spec.spectral_axis>leftbound_new*u.AA) & (spec.spectral_axis<rightbound_new*u.AA))
plt.fill_between(spec.spectral_axis[li], y1=continuum_new, y2=spec.flux[li], alpha = .2)
plt.show()

print("suggested continuum: {:.3f} A ".format(continuum))
print("continuum in use: {:.3f} A ".format(continuum_new))
print("EW with continuum in use: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=continuum_new* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
print("Top error continum: {:.3f} A ".format(continuum*up))
print("Top error: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=(continuum_new * up)* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
print("Lower error continum {:.3f} A ".format(continuum*down))
print("Bottom Error: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=(continuum_new * down)* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
# Out:
# suggested continuum: 7.088 A
# continuum in use: 7.088 A
# EW with continuum in use: 4.574 Angstrom
# Top error continum: 7.443 A
# Top error: 5.124 Angstrom
# Lower error continum 6.734 A
# Bottom Error: 3.966 Angstrom

# %% [markdown]
# H_gamma

# %%
wave = h_gamma

up = (100 + percent_error)/100
down = (100- percent_error)/100

dip_region = (wavelengths < (wave+25)) & (wavelengths > (wave-25)) #central region where the dip occurs
dip_region_rhs = (wavelengths > (wave)) & (wavelengths < (wave+25)) #right hand side within the dip region (helpful for setting right bound)
dip_region_lhs = (wavelengths < (wave)) & (wavelengths > (wave-25)) #left hand side within the dip region

rightregion = (wavelengths < (wave+75)) & (wavelengths > (wave+25)) #region to the right-hand side of dip
leftregion= (wavelengths > (wave-75)) & (wavelengths < (wave-25)) #region to the left-hand side of dip

joined_list = [*flux[rightregion], *flux[leftregion]] #to find continuum, average values from
# the RHS and LHS regions right outside dip region. have to first combine those 2 arrays into
# one long one
continuum = np.average(joined_list) #and then average that new array!
func = interp1d(wavelengths[dip_region], flux[dip_region], kind = 'linear') #linear interpolation of dip region
# (literally connect the dots, but now I can get flux values from the lines connecting the dots)

#create interpolation of RHS so I can find the right bound
x_rhs = np.linspace(wave, wavelengths[dip_region][-1], 5000)
y_rhs = func(x_rhs)

#create interpolation of LHS so I can find the left bound
x_lhs = np.linspace(wavelengths[dip_region][0], wave, 5000)
y_lhs = func(x_lhs)

plt.figure(figsize=(10,8))
plt.plot(spec.spectral_axis, spec.flux)

continuum_new = continuum + 0 #if you think the suggested one is wrong, add/subtract a bit!


tolerance = 0.8 #how close does the continuum need to be to the interpolation?
#can make this small for gradual spikes, big for very sharp spikes
leftbound = x_lhs[(np.abs(y_lhs - continuum_new) < tolerance)][-1] # the [-1] at the end means to 
# take the last array element of this, which would be the most central one (ie the one we want)
# instead of a value on the left or something
rightbound = x_rhs[(np.abs(y_rhs - continuum_new) < tolerance)][0] 


leftbound_new = leftbound + 0
rightbound_new = rightbound + 0


plt.ylim(continuum_new - 10, continuum_new + 5)
plt.xlim(wave-100, wave+100)

plt.plot(wavelengths[dip_region], func(wavelengths[dip_region]))
plt.axvline(rightbound_new, color="orange", linestyle="--", linewidth = "1")
plt.axvline(leftbound_new, color="orange", linestyle="--", linewidth = "1")
plt.axhline(y=continuum_new, color="orange", linestyle="--", linewidth = "1")
plt.axvline(wave, color="blue", linestyle="--", linewidth = "1") #approximate wavelength of line

li = np.where((spec.spectral_axis>leftbound_new*u.AA) & (spec.spectral_axis<rightbound_new*u.AA))
plt.fill_between(spec.spectral_axis[li], y1=continuum_new, y2=spec.flux[li], alpha = .2)
plt.show()

print("suggested continuum: {:.3f} A ".format(continuum))
print("continuum in use: {:.3f} A ".format(continuum_new))
print("EW with continuum in use: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=continuum_new* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
print("Top error continum: {:.3f} A ".format(continuum*up))
print("Top error: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=(continuum_new * up)* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
print("Lower error continum {:.3f} A ".format(continuum*down))
print("Bottom Error: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=(continuum_new * down)* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
# Out:
# suggested continuum: 8.058 A
# continuum in use: 8.058 A
# EW with continuum in use: 6.204 Angstrom
# Top error continum: 8.461 A
# Top error: 6.839 Angstrom
# Lower error continum 7.655 A
# Bottom Error: 5.502 Angstrom

# %% [markdown]
# H_delta

# %%
wave = h_delta

up = (100 + percent_error)/100
down = (100- percent_error)/100

dip_region = (wavelengths < (wave+25)) & (wavelengths > (wave-25)) #central region where the dip occurs
dip_region_rhs = (wavelengths > (wave)) & (wavelengths < (wave+25)) #right hand side within the dip region (helpful for setting right bound)
dip_region_lhs = (wavelengths < (wave)) & (wavelengths > (wave-25)) #left hand side within the dip region

rightregion = (wavelengths < (wave+75)) & (wavelengths > (wave+25)) #region to the right-hand side of dip
leftregion= (wavelengths > (wave-75)) & (wavelengths < (wave-25)) #region to the left-hand side of dip

joined_list = [*flux[rightregion], *flux[leftregion]] #to find continuum, average values from
# the RHS and LHS regions right outside dip region. have to first combine those 2 arrays into
# one long one
continuum = np.average(joined_list) #and then average that new array!
func = interp1d(wavelengths[dip_region], flux[dip_region], kind = 'linear') #linear interpolation of dip region
# (literally connect the dots, but now I can get flux values from the lines connecting the dots)

#create interpolation of RHS so I can find the right bound
x_rhs = np.linspace(wave, wavelengths[dip_region][-1], 5000)
y_rhs = func(x_rhs)

#create interpolation of LHS so I can find the left bound
x_lhs = np.linspace(wavelengths[dip_region][0], wave, 5000)
y_lhs = func(x_lhs)

plt.figure(figsize=(10,8))
plt.plot(spec.spectral_axis, spec.flux)

continuum_new = continuum + 0 #if you think the suggested one is wrong, add/subtract a bit!


tolerance = 0.8 #how close does the continuum need to be to the interpolation?
#can make this small for gradual spikes, big for very sharp spikes
leftbound = x_lhs[(np.abs(y_lhs - continuum_new) < tolerance)][-1] # the [-1] at the end means to 
# take the last array element of this, which would be the most central one (ie the one we want)
# instead of a value on the left or something
rightbound = x_rhs[(np.abs(y_rhs - continuum_new) < tolerance)][0] 


leftbound_new = leftbound +10
rightbound_new = rightbound + 0


plt.ylim(continuum_new - 10, continuum_new + 5)
plt.xlim(wave-100, wave+100)

plt.plot(wavelengths[dip_region], func(wavelengths[dip_region]))
plt.axvline(rightbound_new, color="orange", linestyle="--", linewidth = "1")
plt.axvline(leftbound_new, color="orange", linestyle="--", linewidth = "1")
plt.axhline(y=continuum_new, color="orange", linestyle="--", linewidth = "1")
plt.axvline(wave, color="blue", linestyle="--", linewidth = "1") #approximate wavelength of line

li = np.where((spec.spectral_axis>leftbound_new*u.AA) & (spec.spectral_axis<rightbound_new*u.AA))
plt.fill_between(spec.spectral_axis[li], y1=continuum_new, y2=spec.flux[li], alpha = .2)
plt.show()

print("suggested continuum: {:.3f} A ".format(continuum))
print("continuum in use: {:.3f} A ".format(continuum_new))
print("EW with continuum in use: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=continuum_new* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
print("Top error continum: {:.3f} A ".format(continuum*up))
print("Top error: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=(continuum_new * up)* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
print("Lower error continum {:.3f} A ".format(continuum*down))
print("Bottom Error: {:.3f}".format(equivalent_width(spec, regions=SpectralRegion(leftbound_new*u.AA, rightbound_new*u.AA), continuum=(continuum_new * down)* u.Unit('1e-17 erg cm-2 s-1 AA-1'))))
# Out:
# suggested continuum: 8.755 A
# continuum in use: 8.755 A
# EW with continuum in use: 4.060 Angstrom
# Top error continum: 9.192 A
# Top error: 4.330 Angstrom
# Lower error continum 8.317 A
# Bottom Error: 3.762 Angstrom
